# %% [markdown]
# # Lorentz attractor

# %% [markdown]
# ### Lorenz System
#
# The Lorenz system is given by:
#
#
# $\sigma = 10.0$ $\quad \rho = 28.0 $  $ \quad \beta = \frac{8}{3}$
#
#
# \begin{aligned}
#     \dot{x} &= \sigma (y - x), \\
#     \dot{y} &= x (\rho - z) - y, \\
#     \dot{z} &= x y - \beta z.
# \end{aligned}

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Lorentz system parameters
sigma = 10.0
beta = 8.0 / 3.0
rho = 28.0

# Define the Lorentz system
def lorentz(state, t):
    x, y, z = state
    dxdt = sigma * (y - x)
    dydt = x * (rho - z) - y
    dzdt = x * y - beta * z
    return [dxdt, dydt, dzdt]

# Time points (0 to 50 with 10000 steps)
t = np.linspace(0, 100, 10000)

initial_condition1 = [-10.594887514965762, -15.398070616041126, 22.893945844825783]

# Solve the ODEs for both initial conditions
solution1 = odeint(lorentz, initial_condition1, t)

# Extract trajectories
x1, y1, z1 = solution1.T

print(x1[-1],y1[-1],z1[-1])

# Plotting
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the two attractors
ax.plot(x1, y1, z1, lw=0.5, color='blue', label='Trajectory')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Lorentz Attractor ')
ax.legend()
#plt.show()
# Out:
# 2.0259695212408646 4.9350233690042735 24.11351029714426

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Lorenz system parameters
sigma = 10.0
beta = 8.0 / 3.0
rho = 28.0

# Define the Lorenz system
def lorenz(state, t):
    x, y, z = state
    dxdt = sigma * (y - x)
    dydt = x * (rho - z) - y
    dzdt = x * y - beta * z
    return [dxdt, dydt, dzdt]

# Time points (0 to 100 with 10000 steps)
nt= 10000
t = np.linspace(0, 100, 10000)

# Initial condition
initial_condition = [-10.594887514965762, -15.398070616041126, 22.893945844825783]

# Solve the ODE
solution = odeint(lorenz, initial_condition, t)

# Extract trajectories
x, y, z = solution.T

# Find peaks of z
peaks, _ = find_peaks(z)

# Extract peak times and values
t_peaks = t[peaks]
z_peaks = z[peaks]
N = len(z_peaks )
# Plot the peaks of z with time
plt.figure(figsize=(8, 6))
plt.plot(t, z, label='z(t)', color='blue', alpha=0.5)
plt.scatter(t_peaks, z_peaks, color='red', label='Peaks', marker='o')
plt.xlabel('Time')
plt.ylabel('Z')
plt.title('Peaks of Z over Time')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Lorenz system parameters
sigma = 10.0
beta = 8.0 / 3.0
rho = 28.0

# Define the Lorenz system
def lorenz(state, t):
    x, y, z = state
    dxdt = sigma * (y - x)
    dydt = x * (rho - z) - y
    dzdt = x * y - beta * z
    return [dxdt, dydt, dzdt]

# Time points (0 to 100 with 10000 steps)
nt= 10000
t = np.linspace(0, 100, 10000)

# Initial condition
initial_condition = [-10.594887514965762, -15.398070616041126, 22.893945844825783]

# Solve the ODE
solution = odeint(lorenz, initial_condition, t)

# Extract trajectories
x, y, z = solution.T

# Find peaks of z
peaks, _ = find_peaks(z)

# Extract peak times and values
#t_peaks = t[peaks]
z_peaks = z[peaks]
N = len(z_peaks )
print('Number of peaks = ', N)
print('Number of 1st peaks = ', len(z_peaks[0: N-1]))

plt.figure(figsize=(8, 6))
plt.scatter( z_peaks[0: N-1], z_peaks[1:N], color='red', label='Peaks', marker='o')
plt.xlabel('Time')
plt.ylabel('Z')
plt.title('Peaks of Z over Time')
plt.legend()
plt.grid()
plt.show()
# Out:
# Number of peaks =  135
# Number of 1st peaks =  134
